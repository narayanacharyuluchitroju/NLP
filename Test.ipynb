# %%
ll=[]
for i in range(10):
    ll.append()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 ll=[]
#       2 for i in range(10):
# ----> 3     ll[i][0]=1
#       4     ll[i][1]=2
#
# IndexError: list index out of range

# %%
import pandas as pd
df = pd.DataFrame({'num_legs': [[4, 2],[1,2]], 'num_wings': [0, 2]})

# %%
df
# Out:
#   num_legs  num_wings
# 0   [4, 2]          0
# 1   [1, 2]          2
